# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dense,Dropout
import keras
import numpy as np
import sys
from keras.models import Model
import matplotlib.pyplot as plt
from keras import utils
from keras.optimizers import Adam, RMSprop
from keras.datasets import cifar10
from keras.datasets import cifar100

# %%
def build_alexnet(inputShape,num_classes):
    model = Sequential()
    model.add(Conv2D(96, kernel_size=(3,3), strides = 4, padding='same', activation='relu', input_shape=inputShape))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    model.add(Conv2D(256, kernel_size=(5,5), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    model.add(Conv2D(384, kernel_size=(3,3), padding='same', activation='relu'))
    model.add(Conv2D(384, kernel_size=(3,3), padding='same', activation='relu'))
    model.add(Conv2D(256, kernel_size=(3,3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    model.add(Flatten())
    model.add(Dense(4096))
    model.add(Dropout(0.5))
    model.add(Dense(4096))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer=RMSprop(), metrics=['accuracy'])
    
    return model

# %%
def train_cifar10(dataset):
    
        (x_train, y_train), (x_test, y_test) = dataset.load_data() #original size train(xxx, 28, 28),test(xxx)
        
        #translate the data to image
        x_train = x_train.astype("float32")
        x_test = x_test.astype("float32")

        #normalization
        x_train /= 255
        x_test /= 255

        #translate y_train and y_test to “one hot” form
        y_train = utils.to_categorical(y_train,10) 
        y_test = utils.to_categorical(y_test,10)
        
        
        model = build_alexnet(x_train.shape[1:],10)
        print("\nTraining：")
        model.fit(x_train, y_train, batch_size= 128, epochs= 50)

        # Evaluation
        print("\nEvaluation：")
        final_loss, final_accuracy = model.evaluate(x_test, y_test)
        print("loss= ", final_loss)
        print("accuracy= ", final_accuracy)
    
    
        print("success!")
        model.save('alexnet_cifar10.h5')

# %%
dataset1 = cifar10
train_cifar10(dataset1)
# Out:
# Training：
# Epoch 1/50
# 391/391 [==============================] - 771s 2s/step - loss: 2.5443 - accuracy: 0.1099
# Epoch 2/50
# 391/391 [==============================] - 654s 2s/step - loss: 1.9636 - accuracy: 0.2427
# Epoch 3/50
# 391/391 [==============================] - 618s 2s/step - loss: 1.6494 - accuracy: 0.3908
# Epoch 4/50
# 391/391 [==============================] - 616s 2s/step - loss: 1.4546 - accuracy: 0.4789
# Epoch 5/50
# 391/391 [==============================] - 616s 2s/step - loss: 1.3154 - accuracy: 0.5370
# Epoch 6/50
# 391/391 [==============================] - 619s 2s/step - loss: 1.2009 - accuracy: 0.5774
# Epoch 7/50
# 391/391 [==============================] - 615s 2s/step - loss: 1.0977 - accuracy: 0.6207
# Epoch 8/50
# 391/391 [==============================] - 615s 2s/step - loss: 1.0149 - accuracy: 0.6496
# Epoch 9/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.9472 - accuracy: 0.6742
# Epoch 10/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.8630 - accuracy: 0.7062
# Epoch 11/50
# 391/391 [==============================] - 615s 2s/step - loss: 0.8052 - accuracy: 0.7257
# Epoch 12/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.7519 - accuracy: 0.7445
# Epoch 13/50
# 391/391 [==============================] - 615s 2s/step - loss: 0.7113 - accuracy: 0.7623
# Epoch 14/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.6598 - accuracy: 0.7823
# Epoch 15/50
# 391/391 [==============================] - 618s 2s/step - loss: 0.6239 - accuracy: 0.7943
# Epoch 16/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.5861 - accuracy: 0.8079
# Epoch 17/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.5271 - accuracy: 0.8269
# Epoch 18/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.5010 - accuracy: 0.8387
# Epoch 19/50
# 391/391 [==============================] - 619s 2s/step - loss: 0.4910 - accuracy: 0.8461
# Epoch 20/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.4733 - accuracy: 0.8508
# Epoch 21/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.4407 - accuracy: 0.8618
# Epoch 22/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.4190 - accuracy: 0.8691
# Epoch 23/50
# 391/391 [==============================] - 618s 2s/step - loss: 0.3910 - accuracy: 0.8798
# Epoch 24/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.4104 - accuracy: 0.8766
# Epoch 25/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.3741 - accuracy: 0.8871
# Epoch 26/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.3659 - accuracy: 0.8908
# Epoch 27/50
# 391/391 [==============================] - 618s 2s/step - loss: 0.3360 - accuracy: 0.8984
# Epoch 28/50
# 391/391 [==============================] - 619s 2s/step - loss: 0.3366 - accuracy: 0.8996
# Epoch 29/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.3876 - accuracy: 0.8912
# Epoch 30/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.3230 - accuracy: 0.9069
# Epoch 31/50
# 391/391 [==============================] - 618s 2s/step - loss: 0.3101 - accuracy: 0.9109
# Epoch 32/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.2975 - accuracy: 0.9139
# Epoch 33/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.2889 - accuracy: 0.9165
# Epoch 34/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.3115 - accuracy: 0.9178
# Epoch 35/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.2801 - accuracy: 0.9212
# Epoch 36/50
# 391/391 [==============================] - 620s 2s/step - loss: 0.2852 - accuracy: 0.9228
# Epoch 37/50
# 391/391 [==============================] - 619s 2s/step - loss: 0.2910 - accuracy: 0.9190
# Epoch 38/50
# 391/391 [==============================] - 618s 2s/step - loss: 0.2831 - accuracy: 0.9275
# Epoch 39/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.2817 - accuracy: 0.9246
# Epoch 40/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.2725 - accuracy: 0.9270
# Epoch 41/50
# 391/391 [==============================] - 617s 2s/step - loss: 0.2759 - accuracy: 0.9289
# Epoch 42/50
# 391/391 [==============================] - 621s 2s/step - loss: 0.2681 - accuracy: 0.9315
# Epoch 43/50
# 391/391 [==============================] - 618s 2s/step - loss: 0.2365 - accuracy: 0.9368
# Epoch 44/50
# 391/391 [==============================] - 616s 2s/step - loss: 0.2294 - accuracy: 0.9373
# Epoch 45/50
# 391/391 [==============================] - 618s 2s/step - loss: 0.2527 - accuracy: 0.9356
# Epoch 46/50
# 391/391 [==============================] - 618s 2s/step - loss: 0.2608 - accuracy: 0.9337
# Epoch 47/50
# 391/391 [==============================] - 621s 2s/step - loss: 0.2540 - accuracy: 0.9342
# Epoch 48/50
# 391/391 [==============================] - 621s 2s/step - loss: 0.2521 - accuracy: 0.9376
# Epoch 49/50
# 391/391 [==============================] - 625s 2s/step - loss: 0.2271 - accuracy: 0.9423
# Epoch 50/50
# 391/391 [==============================] - 698s 2s/step - loss: 0.2187 - accuracy: 0.9462
#
# Evaluation：
# 313/313 [==============================] - 19s 58ms/step - loss: 3.8945 - accuracy: 0.5777
# loss=  3.8945469856262207
# accuracy=  0.5777000188827515
# success!

# %%
def train_cifar100(dataset):
    
        (x_train, y_train), (x_test, y_test) = dataset.load_data() #original size train(xxx, 28, 28),test(xxx)
        
        #translate the data to image
        x_train = x_train.astype("float32")
        x_test = x_test.astype("float32")

        #normalization
        x_train /= 255
        x_test /= 255

        #translate y_train and y_test to “one hot” form
        y_train = utils.to_categorical(y_train,100) 
        y_test = utils.to_categorical(y_test,100)
        
        
        model = build_alexnet(x_train.shape[1:],100)
        print("\nTraining：")
        model.fit(x_train, y_train, batch_size= 128, epochs= 50)

        # Evaluation
        print("\nEvaluation：")
        final_loss, final_accuracy = model.evaluate(x_test, y_test)
        print("loss= ", final_loss)
        print("accuracy= ", final_accuracy)
    
    
        print("success!")
        model.save('alexnet_cifar100.h5')

# %%
dataset2 = cifar100
train_cifar100(dataset2)
# Out:
# Training：
# Epoch 1/50
# 391/391 [==============================] - 1324s 3s/step - loss: 4.6972 - accuracy: 0.0148
# Epoch 2/50
# 391/391 [==============================] - 1303s 3s/step - loss: 4.1171 - accuracy: 0.0527
# Epoch 3/50
# 391/391 [==============================] - 1295s 3s/step - loss: 3.7799 - accuracy: 0.1086
# Epoch 4/50
# 391/391 [==============================] - 1293s 3s/step - loss: 3.4952 - accuracy: 0.1538
# Epoch 5/50
# 391/391 [==============================] - 1288s 3s/step - loss: 3.2653 - accuracy: 0.1993
# Epoch 6/50
# 391/391 [==============================] - 1285s 3s/step - loss: 3.0829 - accuracy: 0.2422
# Epoch 7/50
# 391/391 [==============================] - 1284s 3s/step - loss: 2.8770 - accuracy: 0.2802
# Epoch 8/50
# 391/391 [==============================] - 1276s 3s/step - loss: 2.7168 - accuracy: 0.3147
# Epoch 9/50
# 391/391 [==============================] - 1245s 3s/step - loss: 2.5477 - accuracy: 0.3524
# Epoch 10/50
# 391/391 [==============================] - 790s 2s/step - loss: 2.4053 - accuracy: 0.3836
# Epoch 11/50
# 391/391 [==============================] - 555s 1s/step - loss: 2.2674 - accuracy: 0.4115
# Epoch 12/50
# 391/391 [==============================] - 555s 1s/step - loss: 2.0948 - accuracy: 0.4487
# Epoch 13/50
# 391/391 [==============================] - 554s 1s/step - loss: 1.9599 - accuracy: 0.4848
# Epoch 14/50
# 391/391 [==============================] - 556s 1s/step - loss: 1.8252 - accuracy: 0.5157
# Epoch 15/50
# 391/391 [==============================] - 554s 1s/step - loss: 1.6964 - accuracy: 0.5475
# Epoch 16/50
# 391/391 [==============================] - 549s 1s/step - loss: 1.5665 - accuracy: 0.5774
# Epoch 17/50
# 391/391 [==============================] - 547s 1s/step - loss: 1.4765 - accuracy: 0.6027
# Epoch 18/50
# 391/391 [==============================] - 549s 1s/step - loss: 1.4003 - accuracy: 0.6225
# Epoch 19/50
# 391/391 [==============================] - 549s 1s/step - loss: 1.2996 - accuracy: 0.6510
# Epoch 20/50
# 391/391 [==============================] - 548s 1s/step - loss: 1.2410 - accuracy: 0.6669
# Epoch 21/50
# 391/391 [==============================] - 546s 1s/step - loss: 1.1737 - accuracy: 0.6840
# Epoch 22/50
# 391/391 [==============================] - 548s 1s/step - loss: 1.1282 - accuracy: 0.6964
# Epoch 23/50
# 391/391 [==============================] - 546s 1s/step - loss: 1.0426 - accuracy: 0.7160
# Epoch 24/50
# 391/391 [==============================] - 549s 1s/step - loss: 1.0155 - accuracy: 0.7292
# Epoch 25/50
# 391/391 [==============================] - 547s 1s/step - loss: 0.9732 - accuracy: 0.7393
# Epoch 26/50
# 391/391 [==============================] - 549s 1s/step - loss: 0.9464 - accuracy: 0.7539
# Epoch 27/50
# 391/391 [==============================] - 549s 1s/step - loss: 0.9261 - accuracy: 0.7577
# Epoch 28/50
# 391/391 [==============================] - 549s 1s/step - loss: 0.8866 - accuracy: 0.7625
# Epoch 29/50
# 391/391 [==============================] - 548s 1s/step - loss: 0.8849 - accuracy: 0.7756
# Epoch 30/50
# 391/391 [==============================] - 549s 1s/step - loss: 0.8589 - accuracy: 0.7801
# Epoch 31/50
# 391/391 [==============================] - 552s 1s/step - loss: 0.8448 - accuracy: 0.7868
# Epoch 32/50
# 391/391 [==============================] - 551s 1s/step - loss: 0.8343 - accuracy: 0.7900
# Epoch 33/50
# 391/391 [==============================] - 551s 1s/step - loss: 0.7929 - accuracy: 0.7996
# Epoch 34/50
# 391/391 [==============================] - 549s 1s/step - loss: 0.8177 - accuracy: 0.8004
# Epoch 35/50
# 391/391 [==============================] - 551s 1s/step - loss: 0.7632 - accuracy: 0.8104
# Epoch 36/50
# 391/391 [==============================] - 551s 1s/step - loss: 0.7845 - accuracy: 0.8105
# Epoch 37/50
# 391/391 [==============================] - 552s 1s/step - loss: 0.7521 - accuracy: 0.8155
# Epoch 38/50
# 391/391 [==============================] - 554s 1s/step - loss: 0.7569 - accuracy: 0.8151
# Epoch 39/50
# 391/391 [==============================] - 555s 1s/step - loss: 0.7586 - accuracy: 0.8175
# Epoch 40/50
# 391/391 [==============================] - 554s 1s/step - loss: 0.7753 - accuracy: 0.8163
# Epoch 41/50
# 391/391 [==============================] - 559s 1s/step - loss: 0.7244 - accuracy: 0.8296
# Epoch 42/50
# 391/391 [==============================] - 645s 2s/step - loss: 0.7563 - accuracy: 0.8215
# Epoch 43/50
# 391/391 [==============================] - 831s 2s/step - loss: 0.7213 - accuracy: 0.8314
# Epoch 44/50
# 391/391 [==============================] - 1373s 4s/step - loss: 0.7386 - accuracy: 0.8315
# Epoch 45/50
# 391/391 [==============================] - 1343s 3s/step - loss: 0.7601 - accuracy: 0.8279
# Epoch 46/50
# 391/391 [==============================] - 1515s 4s/step - loss: 0.7334 - accuracy: 0.8329
# Epoch 47/50
# 391/391 [==============================] - 1495s 4s/step - loss: 0.7288 - accuracy: 0.8378
# Epoch 48/50
# 391/391 [==============================] - 1400s 4s/step - loss: 0.7593 - accuracy: 0.8329
# Epoch 49/50
# 391/391 [==============================] - 1433s 4s/step - loss: 0.7279 - accuracy: 0.8358
# Epoch 50/50
# 391/391 [==============================] - 1809s 5s/step - loss: 0.7449 - accuracy: 0.8371
#
# Evaluation：
# 313/313 [==============================] - 45s 139ms/step - loss: 9.1153 - accuracy: 0.2662
# loss=  9.11527156829834
# accuracy=  0.2662000060081482
# success!
